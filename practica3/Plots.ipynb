# %%
import matplotlib.pyplot as plt
import sys
import numpy as np

# %%
base_path = '/home/jc/pav/practica3/'

# %%
num='13'

# %%
data = np.loadtxt(base_path+'docs/default/default.f0')
data = np.loadtxt(base_path+'docs/default/default.f0ref')
plt.plot(data)
plt.plot(data2)

# %%
data = np.loadtxt(base_path+'exports/rl0'+num+'.f0')
data2 = np.loadtxt(base_path+'exports/rl0'+num+'.f0ref')
plt.plot(data)
plt.plot(data2)

# %%
data = np.loadtxt(base_path+'plot')

# %%
plt.plot(data)

# %%
data = np.loadtxt(base_path+'plot')
plt.plot(data)
#bottom, top = ylim() 
plt.ylim(-0.5, 0.6)
# Out:
# (-0.5, 0.6)

# %%
sorted(data,reverse=True)
# Out:
# [0.007949,
#  0.003961,
#  0.002317,
#  0.002307,
#  0.002254,
#  0.001889,
#  0.001824,
#  0.001696,
#  0.001668,
#  0.001594,
#  0.001489,
#  0.001364,
#  0.001355,
#  0.00122,
#  0.001163,
#  0.001131,
#  0.001115,
#  0.001065,
#  0.000974,
#  0.00095,
#  0.000941,
#  0.000908,
#  0.00089,
#  0.000871,
#  0.000822,
#  0.000814,
#  0.000807,
#  0.00079,
#  0.000768,
#  0.00075,
#  0.000729,
#  0.000704,
#  0.000697,
#  0.000652,
#  0.000616,
#  0.000595,
#  0.000528,
#  0.000525,
#  0.000495,
#  0.000493,
#  0.000483,
#  0.00048,
#  0.000477,
#  0.000462,
#  0.00046,
#  0.000412,
#  0.000409,
#  0.000407,
#  0.000399,
#  0.000393,
#  0.000364,
#  0.000364,
#  0.000361,
#  0.000356,
#  0.000341,
#  0.000335,
#  0.000328,
#  0.000317,
#  0.00031,
#  0.000307,
#  0.000304,
#  0.000291,
#  0.000283,
#  0.000283,
#  0.000279,
#  0.000278,
#  0.000275,
#  0.000274,
#  0.000272,
#  0.00027,
#  0.000267,
#  0.000265,
#  0.000255,
#  0.000253,
#  0.000253,
#  0.000249,
#  0.000244,
# ...

# %%
data
# Out:
# array([ 7.949e-03,  3.961e-03, -2.326e-03, -4.610e-03, -2.946e-03,
#         2.330e-04,  2.317e-03,  2.254e-03,  1.163e-03,  3.610e-04,
#        -3.550e-04, -1.208e-03, -1.524e-03, -8.690e-04,  2.430e-04,
#         1.065e-03,  1.355e-03,  9.740e-04, -5.330e-04, -1.972e-03,
#        -1.505e-03,  2.530e-04,  1.489e-03,  8.710e-04, -1.009e-03,
#        -2.012e-03, -7.510e-04,  1.364e-03,  1.668e-03,  1.420e-04,
#        -1.547e-03, -2.063e-03, -9.450e-04,  9.410e-04,  1.889e-03,
#         1.115e-03, -5.260e-04, -1.734e-03, -1.564e-03, -2.210e-04,
#         8.220e-04,  7.040e-04, -2.700e-05, -3.710e-04,  1.100e-04,
#         3.560e-04, -3.720e-04, -9.350e-04, -3.950e-04,  9.080e-04,
#         1.696e-03,  6.970e-04, -1.464e-03, -2.121e-03, -2.880e-04,
#         1.824e-03,  2.307e-03,  7.900e-04, -1.427e-03, -2.021e-03,
#        -6.940e-04,  9.500e-04,  1.594e-03,  1.131e-03,  3.500e-05,
#        -8.110e-04, -7.100e-04,  8.000e-06,  3.930e-04,  2.830e-04,
# ...
