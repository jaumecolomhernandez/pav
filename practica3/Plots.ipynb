# %%
import matplotlib.pyplot as plt
import sys
import numpy as np

# %%
base_path = '/home/jc/pav/practica3/'

# %%
data = np.loadtxt(base_path+'exports/n1_n0.txt')
data2 = np.loadtxt(base_path+'exports/power.txt')

# %%
plt.plot(data2)

# %%
plt.plot(data)
