# %%
import matplotlib.pyplot as plt
import sys
import numpy as np

# %%
base_path = '/home/jc/pav/practica3/'

# %%
data = np.loadtxt(base_path+'exports/rl008.f0')
data2 = np.loadtxt(base_path+'exports/rl008.f0ref')

# %%
plt.plot(data)
plt.plot(data2)

# %%
plt.plot(data)
